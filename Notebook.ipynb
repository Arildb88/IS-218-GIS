# %%
Tekniske krav til Notebook: 

Dokumentasjon: Hver kodecelle skal ha en tilhørende Markdown-celle over seg som forklarer hvorfor koden kjøres og hva resultatet forteller oss. 
Verktøy: Vis bruk av minst Pandas, GeoPandas, PostGIS eller DuckDB 
Data Ingest: Les inn minst to ulike datasett (f.eks. en geopackage-fil, geoparquet og en kobling til en database eller API). 
Filtrering & Visualisering: Utfør en attributt- eller romlig filtrering (f.eks. "Finn alle skoler i bydel Sagene") og visualiser resultatet med geopandas.plot() eller folium. 
Vektoranalyser: 
Buffer: Lag en buffersone rundt et utvalg objekter (f.eks. 500m rundt alle kollektivknutepunkt). 
Overlay: Bruk en overlay-operasjon (f.eks. intersection, union eller difference) mellom to lag (f.eks. "Hvilke boligområder ligger innenfor støysonen?"). 
Valgfritt: Bruk flere metoder for vektoranalyser 
Aggregering (Minst 1): Utfør en romlig aggregering. Typisk eksempel: "Tell antall trær (punkter) innenfor hver park (polygon)" eller "Beregn totalt areal av verneområder per kommune". 
Rasteranalyser:  
(kan dokumenteres med cli-kommandoer i markdown) 
Last ned høydedata (DEM) fra valgfritt område.  
Lag et helningskart (slope) og filtrer områder med en viss helning (fks mer enn 30 grader) 
Konverter resultatet av helningskartet til vektordata (polygonize) 
Lag to hillshade ved å endre på parametere i gdal_hillshade
