# %% [markdown]
# ## README
# Kjør i anaconda prompt for å lage geo_env miljø
# conda env create -f environment.yml
# conda activate geo_env

# %% [markdown]
# ## Tilgjengelighet og kapasitet for offentlige tilfluktsrom i Kristiansand
#
# Problemstilling:
# 1. Hvor stor andel av befolkningen bor innenfor 500 m / 1000 m av et offentlig tilfluktsrom?
# 2. Er kapasiteten til tilfluktsrom tilstrekkelig for befolkningen som bor i innenfor disse sonene?
# 3. Finnes det områder der terreng (bratthet) kan gjøre evakuering til tilfluktsrom vanskelig, hvilke tilfluktsrom har en helning på 30 grader eller mer i 50m nærhet fra tilfluktsrommet.

# %%
AREA_NAME = "Kristiansand"
TARGET_CRS = "EPSG:25833"  # meter-basert (UTM33N), egnet for buffer/areal i Norge

# %% [markdown]
# ## Sett arbeidsmappe og importer biblioteker
# Setter opp miljø og filstier slik at det effektivt kan bli brukt senere i opppgaven

# %%
from pathlib import Path
import pandas as pd
import geopandas as gpd
import duckdb

BASE = Path.home() / "Downloads" / "IS-218"
CRS = 25833

# %% [markdown]
# ## Leser inn tilfluktsrom GoeJSON
# Leser inn tilfluktsrom (punkt) for hele Norge og klipper det til Kristiansand.

# %%
from pathlib import Path

tilflukt_dir = BASE / "Samfunnssikkerhet_0000_Norge_25833_TilfluktsromOffentlige_GeoJSON"
tilflukt_files = list(tilflukt_dir.rglob("*.geojson")) + list(tilflukt_dir.rglob("*.json"))

tilflukt_path = tilflukt_files[0]   # <-- dette er en Path
tilflukt_path
# Out:
# WindowsPath('C:/Users/arild/Downloads/IS-218/Samfunnssikkerhet_0000_Norge_25833_TilfluktsromOffentlige_GeoJSON/Samfunnssikkerhet_0000_Norge_25833_TilfluktsromOffentlige_GeoJSON.json')

# %%
files = list(tilflukt_dir.rglob("*.geojson")) + list(tilflukt_dir.rglob("*.json"))
len(files), [f.name for f in files[:10]]
# Out:
# (1, ['Samfunnssikkerhet_0000_Norge_25833_TilfluktsromOffentlige_GeoJSON.json'])

# %% [markdown]
# ## Leser inn kommunepolygon for Kristiansand kommune

# %%
kommune_file = BASE / "Basisdata_0000_Norge_25833_Kommuner_GeoJSON" / "Basisdata_0000_Norge_25833_Kommune_GeoJSON.geojson"
kommuner = gpd.read_file(kommune_file).to_crs(CRS)

krs = kommuner[kommuner["kommunenavn"] == "Kristiansand"].copy()
krs.shape
# Out:
# (1, 15)

# %%
import json
import geopandas as gpd

with open(tilflukt_path, encoding="utf-8") as f:
    data = json.load(f)

tilflukt = gpd.GeoDataFrame.from_features(data["features"], crs=f"EPSG:{CRS}")
tilflukt_krs = gpd.clip(tilflukt, krs)

tilflukt_krs.shape, tilflukt_krs.columns
# Out:
# ((35, 10),
#  Index(['geometry', 'lokalId', 'navnerom', 'versjonId', 'datauttaksdato',
#         'opphav', 'romnr', 'plasser', 'adresse', 'objtype'],
#        dtype='str'))

# %% [markdown]
# ## Koble til DuckDB (filbasert database) og aktiver Spatial SQL
#
# Her oppretter/åpner vi en lokal DuckDB-fil (ingen login). Vi laster `spatial`-utvidelsen slik at vi kan bruke `ST_*`-funksjoner i SQL og lagre geometri som `GEOMETRY` i DuckDB.

# %%
DB_PATH = BASE / "analysis.duckdb"
con = duckdb.connect(str(DB_PATH))

con.execute("INSTALL spatial;")
con.execute("LOAD spatial;")

DB_PATH
# Out:
# WindowsPath('C:/Users/arild/Downloads/IS-218/analysis.duckdb')

# %% [markdown]
# ## Skriv GeoDataFrames til DuckDB som tabeller (med GEOMETRY)
#
# Vi lagrer både kommunepolygonet (Kristiansand) og tilfluktsrom (punkter) i DuckDB.
# Dette gjør at vi kan kjøre romlige SQL-spørringer (f.eks. tellinger, filtrering og joins) i databasen.

# %%
def gdf_to_duckdb(con, gdf, table_name: str):
   
    df = pd.DataFrame(gdf.drop(columns="geometry"))
    df["geom_wkb"] = gdf.geometry.to_wkb()

    con.register(f"_{table_name}_raw", df)
    con.execute(f"DROP TABLE IF EXISTS {table_name};")
    con.execute(f'''
        CREATE TABLE {table_name} AS
        SELECT *,
               ST_GeomFromWKB(geom_wkb) AS geom
        FROM _{table_name}_raw;
    ''')
    con.unregister(f"_{table_name}_raw")

gdf_to_duckdb(con, krs.to_crs(TARGET_CRS), "krs_kommune")
gdf_to_duckdb(con, tilflukt_krs.to_crs(TARGET_CRS), "tilflukt_krs")

con.execute("SELECT 'krs_kommune' AS tabell, COUNT(*) AS n FROM krs_kommune UNION ALL SELECT 'tilflukt_krs', COUNT(*) FROM tilflukt_krs;").df()
# Out:
#          tabell   n
# 0   krs_kommune   1
# 1  tilflukt_krs  35

# %% [markdown]
# ## Spatial SQL-eksempel: Tell tilfluktsrom i Kristiansand
#
# Her bruker vi SQL i DuckDB til å telle antall tilfluktsrom-punkter som ligger innenfor kommunegeometrien.

# %%
con.execute('''
SELECT COUNT(*) AS antall_tilfluktsrom
FROM tilflukt_krs t
JOIN krs_kommune k
  ON ST_Within(t.geom, k.geom);
''').df()
# Out:
#    antall_tilfluktsrom
# 0                   35

# %% [markdown]
# ## Les inn befolkning (FGDB)
# Vi leser inn befolkningsrutenettet (250m) fra en File Geodatabase (FGDB). Først finner vi *.gdb-mappen og lister lagene i den, deretter leser vi riktig lag inn som GeoDataFrame.

# %%
from pathlib import Path
import fiona
import geopandas as gpd

pop_gdb_dir = BASE / "Befolkning_0000_Norge_25833_BefolkningsstatistikkRutenett250m2025_FGDB"

gdb_paths = list(pop_gdb_dir.glob("*.gdb"))
assert len(gdb_paths) > 0, f"Fant ingen .gdb i {pop_gdb_dir}"
gdb = gdb_paths[0]

layers = fiona.listlayers(gdb)
layers
# Out:
# ['befolkningparutenett_befolkningparuter250m']

# %%
layer_name = layers[0]  # 'befolkningsparutenett_befolkningsparuter250m' hos deg
pop = gpd.read_file(gdb, layer=layer_name)
pop.head(), pop.crs, pop.shape
# Out:
# (                 objtype                               lokalid  \
#  0  BefolkningPåRuter250m  72360506-2bbc-4db5-818b-3c92604d66c8
#  1  BefolkningPåRuter250m  b03ac202-9337-4655-9d73-00f692e0e0e9
#  2  BefolkningPåRuter250m  81896cfe-9c39-420a-922f-992b8035320c
#  3  BefolkningPåRuter250m  bc595326-62b4-406d-b234-9c36ba4c02fc
#  4  BefolkningPåRuter250m  274063d2-8734-4624-8537-fabeba4ece01
#
#                                              navnerom versjonid  \
#  0  http://data.geonorge.no/sosi/befolkning/befolk...  20250101
#  1  http://data.geonorge.no/sosi/befolkning/befolk...  20250101
#  2  http://data.geonorge.no/sosi/befolkning/befolk...  20250101
#  3  http://data.geonorge.no/sosi/befolkning/befolk...  20250101
#  4  http://data.geonorge.no/sosi/befolkning/befolk...  20250101
#
#    oppdateringsdato      datauttaksdato opphav       ssbid250m  poptot  \
#  0       2025-01-01 2025-10-06 10:20:59    SSB  19580006626500      21
#  1       2025-01-01 2025-10-06 10:20:59    SSB  19580006626250      15
#  2       2025-01-01 2025-10-06 10:20:59    SSB  19577506626500      10
#  3       2025-01-01 2025-10-06 10:20:59    SSB  19577506627000       9
#  4       2025-01-01 2025-10-06 10:20:59    SSB  19577506626750      12
#
#     statistikkar                                           geometry
#  0          2025  MULTIPOLYGON (((-41749.984 6626499.934, -41999...
#  1          2025  MULTIPOLYGON (((-41749.984 6626249.934, -41999...
#  2          2025  MULTIPOLYGON (((-41999.984 6626499.934, -42249...
#  3          2025  MULTIPOLYGON (((-41999.984 6626999.934, -42249...
#  4          2025  MULTIPOLYGON (((-41999.984 6626749.934, -42249...  ,
#  <Projected CRS: EPSG:25833>
#  Name: ETRS89 / UTM zone 33N
#  Axis Info [cartesian]:
#  - E[east]: Easting (metre)
#  - N[north]: Northing (metre)
#  Area of Use:
#  - name: Europe between 12°E and 18°E: Austria; Croatia; Denmark - offshore and offshore; Germany - onshore and offshore; Italy - onshore and offshore; Norway including Svalbard - onshore and offshore.
#  - bounds: (12.0, 34.79, 18.01, 84.01)
#  Coordinate Operation:
#  - name: UTM zone 33N
#  - method: Transverse Mercator
#  Datum: European Terrestrial Reference System 1989 ensemble
#  - Ellipsoid: GRS 1980
#  - Prime Meridian: Greenwich,
#  (224761, 11))

# %%
pop.columns
# Out:
# Index(['objtype', 'lokalid', 'navnerom', 'versjonid', 'oppdateringsdato',
#        'datauttaksdato', 'opphav', 'ssbid250m', 'poptot', 'statistikkar',
#        'geometry'],
#       dtype='str')

# %% [markdown]
# ## Avgrens til Kristiansand for å gjøre videre analyser
# Lastet ned kommunegrenser fra Geonorge.no og lagt til i mappen med alle filer.

# %%
kommune_file = BASE / "Basisdata_0000_Norge_25833_Kommuner_GeoJSON" / "Basisdata_0000_Norge_25833_Kommune_GeoJSON.geojson"

kommuner = gpd.read_file(kommune_file).to_crs(25833)

kommuner.geometry.geom_type.value_counts()
# Out:
# MultiPolygon    357
# Name: count, dtype: int64

# %%
krs = kommuner[kommuner["kommunenavn"] == "Kristiansand"].copy()
krs = krs.to_crs(25833)

krs.shape
# Out:
# (1, 15)

# %% [markdown]
# ## Klipp ut data til Kristiansand

# %%
tilflukt_krs = gpd.clip(tilflukt, krs)
pop_krs = gpd.clip(pop, krs)

tilflukt_krs.shape, pop_krs.shape
# Out:
# ((35, 10), (2143, 11))

# %% [markdown]
# ## DuckDB: Spatial SQL analyse
# I denne delen bruker vi DuckDB som databaseverktøy og kjører Spatial SQL (ST_Within/ST_Distance) på de samme datasettene som vi analyserer i GeoPandas. Dette oppfyller kravet om å vise bruk av databaseverktøy i notebooken.

# %%
import duckdb

db_path = BASE / "analysis.duckdb"
con = duckdb.connect(str(db_path))

con.execute("INSTALL spatial;")
con.execute("LOAD spatial;")

til_sql = tilflukt_krs.copy()
til_sql["geom_wkb"] = til_sql.geometry.to_wkb()

krs_sql = krs.copy()
krs_sql["geom_wkb"] = krs_sql.geometry.to_wkb()

con.register("til_raw", til_sql.drop(columns="geometry"))
con.register("krs_raw", krs_sql.drop(columns="geometry"))

con.execute("""
CREATE OR REPLACE TABLE tilflukt AS
SELECT *, ST_GeomFromWKB(geom_wkb) AS geom
FROM til_raw;
""")

con.execute("""
CREATE OR REPLACE TABLE kommune AS
SELECT *, ST_GeomFromWKB(geom_wkb) AS geom
FROM krs_raw;
""")

con.execute("""
SELECT COUNT(*) AS antall_tilfluktsrom
FROM tilflukt t
JOIN kommune k
  ON ST_Within(t.geom, k.geom);
""").df()
# Out:
#    antall_tilfluktsrom
# 0                   35

# %% [markdown]
# ## Lager buffersone rundt tilfluktsrom for å representere mulig gangavstand. Her brukes 500 m og 1000 m for å sammenligne dekning

# %%
import pandas as pd

distances = [500, 1000]  # meter

buffers = []

for d in distances:
    b = tilflukt_krs.copy()
    b["buffer_m"] = d
    b["geometry"] = b.buffer(d)
    buffers.append(b[["buffer_m", "geometry"]])

buffer_gdf = pd.concat(buffers, ignore_index=True)
buffer_gdf.head()
# Out:
#    buffer_m                                           geometry
# 0       500  POLYGON ((94609.001 6469442.999, 94606.594 646...
# 1       500  POLYGON ((91775.001 6469579.999, 91772.594 646...
# 2       500  POLYGON ((94493.001 6469719.999, 94490.594 646...
# 3       500  POLYGON ((94227.001 6469958.999, 94224.594 646...
# 4       500  POLYGON ((91381.001 6472180.999, 91378.594 647...

# %% [markdown]
# ## Slå sammen til en flate per avstand

# %%
buffer_union = buffer_gdf.dissolve(by="buffer_m").reset_index()
buffer_union
# Out:
#    buffer_m                                           geometry
# 0       500  MULTIPOLYGON (((88080.962 6458343.3, 88055.736...
# 1      1000  MULTIPOLYGON (((88471.471 6458023.429, 88413.0...

# %% [markdown]
# ## Lag utsnitt for Kristiansand midlertidig
# Jeg lastet ned osm kart for hele norge med vann, veier, bygninger og natur.
# hentet ut et utsnitt over Kristiansand kommune og lagret dette i en geopackage fil.
# Dette krevde at en 6GB stor mappe måtte være i prosjektet så for å unngå dette ved en levering, har vi bare tatt med filen for Kristiansand.

# %%
import geopandas as gpd
from pathlib import Path

BASE = Path.home() / "Downloads" / "IS-218"
osm_file = BASE / "norway-260228-free.shp"
out_file = BASE / "kristiansand_background.gpkg"

osm_meta = gpd.read_file(osm_file, layer="gis_osm_water_a_free_1", rows=1)
osm_crs = osm_meta.crs
print("OSM CRS:", osm_crs)
print("Kristiansand CRS:", krs.crs)

krs_osm = krs.to_crs(osm_crs)
bbox = tuple(krs_osm.total_bounds)

water = gpd.read_file(osm_file, layer="gis_osm_water_a_free_1", bbox=bbox)
nature = gpd.read_file(osm_file, layer="gis_osm_natural_a_free_1", bbox=bbox)
roads = gpd.read_file(osm_file, layer="gis_osm_roads_free_1", bbox=bbox)
buildings = gpd.read_file(osm_file, layer="gis_osm_buildings_a_free_1", bbox=bbox)

water = water.to_crs(krs.crs)
nature = nature.to_crs(krs.crs)
roads = roads.to_crs(krs.crs)
buildings = buildings.to_crs(krs.crs)

water_krs = gpd.clip(water, krs)
nature_krs = gpd.clip(nature, krs)
roads_krs = gpd.clip(roads, krs)
buildings_krs = gpd.clip(buildings, krs)

if "fclass" in roads_krs.columns:
    roads_krs = roads_krs[roads_krs["fclass"].isin([
        "motorway", "trunk", "primary", "secondary", "tertiary", "residential"
    ])].copy()

if len(buildings_krs) > 5000:
    buildings_krs = buildings_krs.sample(5000, random_state=42)

print("water_krs:", len(water_krs))
print("nature_krs:", len(nature_krs))
print("roads_krs:", len(roads_krs))
print("buildings_krs:", len(buildings_krs))

water_krs.to_file(out_file, layer="water", driver="GPKG")
nature_krs.to_file(out_file, layer="nature", driver="GPKG")
roads_krs.to_file(out_file, layer="roads", driver="GPKG")
buildings_krs.to_file(out_file, layer="buildings", driver="GPKG")

print(f"Lagret til: {out_file}")
# Out:
# OSM CRS: EPSG:4326
# Kristiansand CRS: EPSG:25833
# water_krs: 5750
# nature_krs: 92
# roads_krs: 4364
# buildings_krs: 5000
# Lagret til: C:\Users\arild\Downloads\IS-218\kristiansand_background.gpkg

# %% [markdown]
# ## Hente ut informasjonen som er i Kristiansand.gpkg filen for å bruke i Visualisering av data

# %%
background_file = BASE / "kristiansand_background.gpkg"

water_krs = gpd.read_file(background_file, layer="water")
nature_krs = gpd.read_file(background_file, layer="nature")
roads_krs = gpd.read_file(background_file, layer="roads")
buildings_krs = gpd.read_file(background_file, layer="buildings")

# %% [markdown]
# ## Visualisering av data

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

fig, ax = plt.subplots(figsize=(8, 8))

nature_krs.plot(ax=ax, color="#dfeadf", edgecolor="none")
water_krs.plot(ax=ax, color="#bcdff5", edgecolor="none")
buildings_krs.plot(ax=ax, color="#d9d9d9", edgecolor="none")
roads_krs.plot(ax=ax, color="gray", linewidth=0.4, alpha=0.7)

krs.boundary.plot(ax=ax, linewidth=1, color="black")

buffer_union.plot(ax=ax, alpha=0.2, color="gray")

tilflukt_krs.plot(ax=ax, color="red", markersize=20)

legend_elements = [
    Line2D([0], [0], color="black", lw=1, label="Kristiansand kommunegrense"),
    Patch(facecolor="#dfeadf", edgecolor="none", label="Natur"),
    Patch(facecolor="#bcdff5", edgecolor="none", label="Vann"),
    Line2D([0], [0], color="gray", lw=1, label="Veier"),
    Patch(facecolor="#d9d9d9", edgecolor="none", label="Bygninger"),
    Patch(facecolor="gray", edgecolor="gray", alpha=0.2, label="Buffer (500/1000 m)"),
    Line2D([0], [0], marker="o", color="w", label="Tilfluktsrom",
           markerfacecolor="red", markersize=8),
]

ax.legend(handles=legend_elements, loc="lower left")
ax.set_title("Tilfluktsrom og buffersone i Kristiansand (UTM33)")
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Visualisering av data

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

fig, ax = plt.subplots(figsize=(8, 8))

nature_krs.plot(ax=ax, color="#dfeadf", edgecolor="none")
water_krs.plot(ax=ax, color="#bcdff5", edgecolor="none")
buildings_krs.plot(ax=ax, color="#d9d9d9", edgecolor="none")
roads_krs.plot(ax=ax, color="gray", linewidth=0.4, alpha=0.7)

krs.boundary.plot(ax=ax, linewidth=1, color="black")

buffer_union.plot(ax=ax, alpha=0.2, color="gray")

tilflukt_krs.plot(ax=ax, color="red", markersize=20)

legend_elements = [
    Line2D([0], [0], color="black", lw=1, label="Kristiansand kommunegrense"),
    Patch(facecolor="#dfeadf", edgecolor="none", label="Natur"),
    Patch(facecolor="#bcdff5", edgecolor="none", label="Vann"),
    Line2D([0], [0], color="gray", lw=1, label="Veier"),
    Patch(facecolor="#d9d9d9", edgecolor="none", label="Bygninger"),
    Patch(facecolor="gray", edgecolor="gray", alpha=0.2, label="Buffer (500/1000 m)"),
    Line2D([0], [0], marker="o", color="w", label="Tilfluktsrom",
           markerfacecolor="red", markersize=8),
]

ax.legend(handles=legend_elements, loc="lower left")
ax.set_title("Tilfluktsrom og buffersone i Kristiansand (UTM33)")
ax.set_axis_off()

plt.show()

# %% [markdown]
# ## Hvor mange mennesker bor i områder som ligger innenfor rekkevidde
# Vi beregner hvor mange som bor innenfor 500m og 1000m fra tilfluktsrom ved å gjøre en overlay (intersection) mellom befolkningsruter og bufferflatene. For å unngå dobbelttelling summerer vi per unik rute-id (ssbid250m). Til slutt sammenligner vi mot total befolkning i hele Kristiansand kommune.

# %%
POP_COL = "poptot"
ID_COL = "ssbid250m"

buffer_500 = buffer_union[buffer_union["buffer_m"] == 500].copy()
buffer_1000 = buffer_union[buffer_union["buffer_m"] == 1000].copy()

pop_in_500 = gpd.overlay(pop_krs[[ID_COL, POP_COL, "geometry"]], buffer_500, how="intersection")
pop_in_1000 = gpd.overlay(pop_krs[[ID_COL, POP_COL, "geometry"]], buffer_1000, how="intersection")

bef_500 = pop_in_500.drop_duplicates(ID_COL)[POP_COL].sum()
bef_1000 = pop_in_1000.drop_duplicates(ID_COL)[POP_COL].sum()
bef_total = pop_krs[POP_COL].sum()

df_bef = pd.DataFrame({
    "Område": ["Innen 500m", "Innen 1000m", "Hele kommunen"],
    "Befolkning": [bef_500, bef_1000, bef_total]
})
df_bef["Andel av kommunen"] = df_bef["Befolkning"] / bef_total

df_bef
# Out:
#           Område  Befolkning  Andel av kommunen
# 0     Innen 500m       55379           0.467696
# 1    Innen 1000m       81686           0.689869
# 2  Hele kommunen      118408           1.000000

# %% [markdown]
# ## Total kapasitet i kommunen for alle tilfluktsrom

# %%
total_kapasitet = tilflukt_krs["plasser"].sum()
total_kapasitet
# Out:
# np.int64(7281)

# %% [markdown]
# ## Sammenligne kapasitet på tilfluktsrom og befolkningsantall i Krisitansand kommune
#
# Kapasiten til tilfluktsrommene er avgjørende for reell dekning.
# Selv om et rom er innenfor akseptabel avstand, kan kapasiteten være utilstrekkelig for befolkningen i område
#
# Vi sammenligner samlet kapasitet i tilfluktsrom med befolkningen innenfor 500m, 1000m og hele kommunen for å få en enkel indikator på om kapasiteten kan være tilstrekkelig.
#
# Dekningen viser at det er omtrent 6% av befolkningen innenfor analyseområde som vil kunne få plass i tilfluktsrommet. Dette indikerer en betydelig underdektning dersom alle innbyggere skulle ha behov for tilfluktsrom samtidig.

# %%
KAP_COL = "plasser"
total_kapasitet = tilflukt_krs[KAP_COL].sum()

df_kap = pd.DataFrame({
    "Område": ["Innen 500m", "Innen 1000m", "Hele kommunen"],
    "Befolkning": [bef_500, bef_1000, bef_total],
    "Total kapasitet": [total_kapasitet, total_kapasitet, total_kapasitet]
})

df_kap["Kapasitet per person"] = df_kap["Total kapasitet"] / df_kap["Befolkning"]
df_kap["Dekningsgrad (%)"] = 100 * df_kap["Kapasitet per person"]

df_kap
# Out:
#           Område  Befolkning  Total kapasitet  Kapasitet per person  \
# 0     Innen 500m       55379             7281              0.131476
# 1    Innen 1000m       81686             7281              0.089134
# 2  Hele kommunen      118408             7281              0.061491
#
#    Dekningsgrad (%)
# 0         13.147583
# 1          8.913400
# 2          6.149078

# %% [markdown]
# ## Dekningskart for å vise område som blir dekket av et tilfluktsrom

# %%
ax = nature_krs.plot(figsize=(9,9), color="#dfeadf", edgecolor="none")

water_krs.plot(ax=ax, color="#bcdff5", edgecolor="none")
buildings_krs.plot(ax=ax, color="#d9d9d9", edgecolor="none")
roads_krs.plot(ax=ax, color="gray", linewidth=0.4, alpha=0.7)

krs.boundary.plot(ax=ax, linewidth=1, color="black")

buffer_1000.plot(ax=ax, alpha=0.15)
buffer_500.plot(ax=ax, alpha=0.25)

tilflukt_krs.plot(ax=ax, markersize=8, color="red")

ax.set_title("Dekningssoner for tilfluktsrom (500m og 1000m)")
ax.set_axis_off()

plt.show()

# %% [markdown]
# ## Rasteranalyse (DEM , slope, >30 grader, polygonize, hillshade
# I denne delen dokumenteres rasterarbeidsflyten med GDAL CLI. Vi bruker en DEM (GeoTIFF) for et valgt område i/ved Kristiansand.
#
# Områder med helning over 30 grader kan være vanskeligere å ferdes i, og kan dermed påvirke reell tilgjengelighet til tilfluktsrom i en evakueringssituasjon

# %% [markdown]
# ## Slår sammen raster filene for å lage en fil som har innholdet til alle filene i Anaconda prompt
# python C:\Users\arild\anaconda3\envs\geo_env\Scripts\gdal_merge.py -o dem_merge.tif Tif_data\6501_3_10m_z33.tif Tif_data\6500_3_10m_z33.tif Tif_data\6500_2_10m_z33.tif Tif_data\6401_4_10m_z33.tif Tif_data\6401_3_10m_z33.tif Tif_data\6400_4_10m_z33.tif Tif_data\6400_3_10m_z33.tif Tif_data\6400_2_10m_z33.tif Tif_data\6400_1_10m_z33.tif

# %% [markdown]
# ## Lager helningskart
# gdaldem slope dem_merge.tif slope.tif

# %% [markdown]
# ## Filtrer områder med helning >30 grader, endre målmappe til riktig bruker
# python C:\Users\arild\anaconda3\envs\geo_env\Scripts\gdal_calc.py -A slope.tif --outfile=slope_gt30.tif --calc="A>30" --NoDataValue=0

# %% [markdown]
# ## Polygonize helningsfilen, endre målmappen til riktig bruker
# python C:\Users\arild\anaconda3\envs\geo_env\Scripts\gdal_polygonize.py slope_gt30.tif -f "GPKG" slope_gt30.gpkg bratthet layer_bratthet

# %% [markdown]
# ## Les inn helningsfilen for å kunne bruke den i Hillshade

# %%
import geopandas as gpd
from pathlib import Path

BASE = Path.home() / "Downloads" / "IS-218"

bratt_file = BASE / "slope_gt30.gpkg"

bratt = gpd.read_file(bratt_file, layer="bratthet")

# samme CRS som resten av analysen
bratt = bratt.to_crs(krs.crs)

print(bratt.head())
print("Antall polygoner:", len(bratt))
# Out:
#    layer_bratthet                                           geometry
# 0               1  POLYGON ((10125 6550195, 10125 6550185, 10145 ...
# 1               1  POLYGON ((17375 6550195, 17375 6550185, 17395 ...
# 2               1  POLYGON ((21955 6550195, 21955 6550185, 21985 ...
# 3               1  POLYGON ((24915 6550195, 24915 6550185, 24925 ...
# 4               1  POLYGON ((26235 6550195, 26235 6550185, 26245 ...
# Antall polygoner: 227321

# %% [markdown]
# ## Klipp til kartet til Kristiansand for å gjøre det lettere med analysen

# %%
bratt = gpd.clip(bratt, krs)

# %% [markdown]
# ## Kart for å sjekke at terrenger ser "normalt" ut før vi fortsetter med analysen.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 8))
krs.plot(ax=ax, facecolor="none", edgecolor="black", linewidth=1)
bratt.plot(ax=ax, color="orange", alpha=0.5)

ax.set_title("Kontroll: bratt terreng og Kristiansand")
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Kjør 50m bufferanalysen, denne viser at det er 5 tilfluktrom som har helning på over 30 grader innen 50m fra tilfluktsrommet.

# %%
tilflukt_50m = tilflukt_krs.copy()
tilflukt_50m["geometry"] = tilflukt_50m.geometry.buffer(50)

bratt_union = bratt.union_all()
tilflukt_50m["bratt_50m"] = tilflukt_50m.intersects(bratt_union)

print(tilflukt_50m["bratt_50m"].value_counts())
# Out:
# bratt_50m
# False    30
# True      5
# Name: count, dtype: int64

# %% [markdown]
# ## Henter ut de 5 tilfluktsrommene som har helning

# %%
tilflukt_bratt = tilflukt_krs[tilflukt_50m["bratt_50m"]].copy()
print("Antall tilfluktsrom med >30° innen 50 m:", len(tilflukt_bratt))
# Out:
# Antall tilfluktsrom med >30° innen 50 m: 5

# %% [markdown]
# ## Lager et oversiktskart som viser de 5 tilfluktsstedene som har helning over 30 grader innen 50m

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

tilflukt_bratt = tilflukt_krs[tilflukt_50m["bratt_50m"]].copy()

ax = nature_krs.plot(figsize=(9, 9), color="#dfeadf", edgecolor="none")

water_krs.plot(ax=ax, color="#bcdff5", edgecolor="none")
buildings_krs.plot(ax=ax, color="#d9d9d9", edgecolor="none")
roads_krs.plot(ax=ax, color="gray", linewidth=0.4, alpha=0.7)

krs.boundary.plot(ax=ax, linewidth=1, color="black")
bratt.plot(ax=ax, color="orange", alpha=0.35)

tilflukt_krs.plot(ax=ax, markersize=8, color="red")
tilflukt_bratt.plot(ax=ax, markersize=30, color="darkred")

legend_elements = [
    Line2D([0], [0], color="black", lw=1, label="Kristiansand kommunegrense"),
    Patch(facecolor="#dfeadf", edgecolor="none", label="Natur"),
    Patch(facecolor="#bcdff5", edgecolor="none", label="Vann"),
    Line2D([0], [0], color="gray", lw=1, label="Veier"),
    Patch(facecolor="#d9d9d9", edgecolor="none", label="Bygninger"),
    Patch(facecolor="orange", edgecolor="none", alpha=0.35, label="Bratt terreng >30°"),
    Line2D([0], [0], marker="o", color="w", label="Tilfluktsrom",
           markerfacecolor="red", markersize=8),
    Line2D([0], [0], marker="o", color="w", label="Tilfluktsrom med >30° innen 50 m",
           markerfacecolor="darkred", markersize=10),
]

ax.legend(handles=legend_elements, loc="lower left")
ax.set_title("Tilfluktsrom med bratt terreng (>30°) innen 50 m")
ax.set_axis_off()
plt.show()

# %% [markdown]
# ## Konklusjon over analysen
#
# Analysen viser at det finnes 35 tilfluktsrom i Kristiansand kommune. Ved å etablere buffersoner på 500 meter og 1000 meter rundt hvert tilfluktsrom har vi analysert hvor mange innbyggere som bor innenfor gangavstand til et tilfluktsrom.
#
# Resultatene viser at en betydelig andel av befolkningen bor innenfor 1000 meter fra et tilfluktsrom, mens færre bor innenfor 500 meter. Når dette sammenlignes med den totale kapasiteten i tilfluktsrommene (antall tilgjengelige plasser), ser vi at kapasiteten er betydelig lavere enn antall innbyggere innenfor dekningssonene. Dette indikerer at selv om mange geografisk sett bor nær et tilfluktsrom, er det ikke tilstrekkelig kapasitet til å dekke hele befolkningen.
#
# Rasteranalysen av terreng (helning > 30 grader) viser at fem tilfluktsrom har bratt terreng innenfor en radius på 50 meter fra tilfluktsrommet. Slike bratte områder kan påvirke den faktiske tilgjengeligheten i en evakueringssituasjon, selv om de ligger innenfor teoretisk gangavstand. Terrengforhold er derfor en viktig faktor som kan redusere reell tilgjengelighet sammenlignet med beregnet avstand.
#
# Samlet sett viser analysen at geografisk dekning alene ikke er tilstrekkelig for å vurdere beredskap. Både kapasitet og terrengforhold må tas i betraktning for å gi et mer realistisk bilde av hvor godt kommunen er rustet i en krisesituasjon. Analysen illustrerer hvordan romlige analyser kan bidra til å identifisere potensielle svakheter i beredskapsinfrastruktur, i tråd med tematikken rundt totalforsvar og samfunnssikkerhet.
